# %%
# %cd /home/jeongmin/genai
# %run backend/pipeline_test.py
# Out:
# /home/jeongmin/genai
# LAB(lips, cheeks, eyeshadow):
#   lips      -> (162.86, 157.54, 138.82)
#   cheeks    -> (204.93, 139.36, 137.15)
#   eyeshadow -> (191.03, 139.43, 137.29)
#
# ΔE(lips vs cheeks) = 45.861
# ΔE(lips vs eyeshadow) = 33.526
# ΔE(cheeks vs eyeshadow) = 13.901
#
# 저장 폴더: /home/jeongmin/genai/debug_out
# I0000 00:00:1762254163.413285  136078 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762254163.536896  136836 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 580.95.05), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1762254163.551286  136805 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762254163.580438  136810 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# %run etude_crawler.py
# Out:
# === ETUDE 크롤러 시작 ===
#
# [1단계] 제품 목록 수집 중...
#    → 총 12개 제품 발견
#
# [2단계] 제품 상세 정보 수집 중...
#
# [1/5] NEW
#
# [2/5] NEW
#
# [3/5] NEW
#
# [4/5] NEW
#
# [5/5] Select options
#
# === 크롤링 완료 ===
# 총 0개 색상 수집
# 저장 위치: data/etude/etude_eyeshadow.json
#
# 수집된 데이터 샘플:
