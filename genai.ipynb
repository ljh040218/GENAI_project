# %%
# %cd /home/jeongmin/genai/data/product
# %run import_csv_to_vector.py
# Out:
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/jeongmin/genai/data/product
#
# lips 데이터 처리 시작: lip_dataset_with_id.csv
# 총 234개 중 234개 처리
#    -> 10개 저장 완료...
#    -> 20개 저장 완료...
#    -> 30개 저장 완료...
#    -> 40개 저장 완료...
#    -> 50개 저장 완료...
#    -> 60개 저장 완료...
#    -> 70개 저장 완료...
#    -> 80개 저장 완료...
#    -> 90개 저장 완료...
#    -> 100개 저장 완료...
#    -> 110개 저장 완료...
#    -> 120개 저장 완료...
#    -> 130개 저장 완료...
#    -> 140개 저장 완료...
#    -> 150개 저장 완료...
#    -> 160개 저장 완료...
#    -> 170개 저장 완료...
#    -> 180개 저장 완료...
#    -> 190개 저장 완료...
#    -> 200개 저장 완료...
#    -> 210개 저장 완료...
#    -> 220개 저장 완료...
#    -> 230개 저장 완료...
# ✅ lips 완료: 234개
#
#
# cheeks 데이터 처리 시작: cheek_dataset_with_id.csv
# 총 169개 중 169개 처리
#    -> 10개 저장 완료...
# ...

# %%
# %cd /home/jeongmin/genai/beauty-ai-python/app
# %run  verify_db_connection.py
# Out:
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/jeongmin/genai/beauty-ai-python/app
# ...
# Railway DB ↔ Neon Vector DB 연결 검증
# ...
#
# 🚀 검증 시작...
#
#
# ### 1. Railway DB 연결 테스트
# --------------------------------------------------------------------------------
# ✅ Railway DB 연결 성공
#
# 📊 사용자 목록 (최대 5명):
#    - ID: d8a295ce-921a-4b47-a0b5-84fd7dc8c886, Username: 1, Email: 111@shin.com
#    - ID: f09128d3-8cdb-4a5f-a45a-1a7db9939889, Username: 123, Email: 123@test.com
#    - ID: 78a9afb9-15c9-48a0-9960-e4edc3c0e546, Username: 사람, Email: test1@test.com
#    - ID: 40ead98a-7d17-4200-a4ba-0d8e72f0f889, Username: 124, Email: 124@test.com`
#    - ID: 3e66300d-54ba-4907-aad2-cd71287164fc, Username: 124111, Email: 12411@test.com
#
# 📊 사용자 프로필 연결:
# ...

# %%
# %cd /home/jeongmin/genai/data/product
# %run dataset_id.py
# Out:
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/jeongmin/genai/data/product
# ...
# 전체 제품 매칭 시작
# ...
#
# Products 테이블에서 데이터 가져오는 중...
# 총 673개 제품 로드 완료
#
# DB 브랜드 목록 (샘플):
#   - 3CE
#   - Clio
#   - Lilybyred
#   - Naming
#   - Peripera
#   - Rom&nd
#   - VDL
#   - hince
#   - 더샘
#   - 데이지크
#   - 디어달리아
#   - 딘토
#   - 라카
#   - 롬앤
#   - 삐아
#   ... 총 30개 브랜드
#
# lip_dataset.csv (인코딩: cp949):
#   CSV 총 234개 제품
#   예시: 롬앤 | 롬앤X조앤프렌즈 더 쥬시 래스팅 틴트 | 03 베어그레이프
#   총 234개 중 234개 매칭 성공 (100.0%)
#   매칭 실패: 0개
#   저장 완료: lip_dataset_with_id.csv
#
# cheek_dataset.csv (인코딩: utf-8):
#   CSV 총 169개 제품
#   예시: 3CE | 무드레시피 페이스 블러쉬 | 누드 피치
#   총 169개 중 169개 매칭 성공 (100.0%)
#   매칭 실패: 0개
#   저장 완료: cheek_dataset_with_id.csv
#
# eyeshadow_dataset.csv (인코딩: utf-8):
#   CSV 총 245개 제품
# ...

# %%
# !pip install psycopg2-binary --break-system-packages

# %%
# %cd /home/jeongmin/genai/data
# %run analyze_and_visualize_lab.py
# Out:
# /home/jeongmin/genai/data
# 얼굴 메이크업 ROI LAB 색상 분석
#
# ...
# LAB 값 유효성 검사
# ...
#
# 심각한 오류: 없음
#
# 경고: 없음
#
# ...
#
# 처리를 계속합니다...
#
#
# CSV 저장 완료: /home/jeongmin/genai/debug_out/lab_colors.csv
# HTML 저장 완료: /home/jeongmin/genai/debug_out/lab_colors.html
#
# 완료!
# CSV: /home/jeongmin/genai/debug_out/lab_colors.csv
# HTML: /home/jeongmin/genai/debug_out/lab_colors.html
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %cd /home/jeongmin/genai/backend
# %run pipeline_test.py
# Out:
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/jeongmin/genai/backend
# ...
# 셀럽 이미지 ROI 추출 시작
# ...
#
# ...
# JENNIE 폴더 처리 시작 (54개 이미지)
# ...
#
# [1/54] 처리 중: 1.jpg
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763135709.032215 1186154 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763135709.100149 2103107 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 580.95.05), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1763135709.109167 2103082 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...

# %%
# %cd /home/jeongmin/genai/data
# %run build_product_db.py
# Out:
# /home/jeongmin/genai/data
# === K-뷰티 제품 데이터베이스 구축 ===
#
# 1. 데이터베이스 스키마 생성...
# 데이터베이스 생성 완료: /home/jeongmin/genai/data/db/products.db
#
# 2. CSV 파일 import...
#
# 처리 중: 투크_새틴_도화밤.csv
#   삽입 완료: 13개 제품
#
# 처리 중: 홀리카홀리카_마이페이브_피스_아이섀도우.csv
#   삽입 완료: 84개 제품
#
# 처리 중: 데이지크_블루밍_싱글_섀도우.csv
#   삽입 완료: 10개 제품
#
# 처리 중: 삐아_레디_투_웨어_아이섀도우.csv
#   삽입 완료: 6개 제품
#
# 처리 중: 에뛰_왓츠_인_마이_아이즈_&_더블.csv
#   삽입 완료: 10개 제품
#
# 처리 중: 더샘_샘물_싱글_섀도우.csv
#   삽입 완료: 35개 제품
#
# 처리 중: 아멜리_섀도.csv
#   삽입 완료: 26개 제품
#
# 처리 중: 라카_모노_아이섀도우.csv
#   삽입 완료: 26개 제품
#
# 처리 중: 롬앤_슬라이드_인_싱글.csv
#   삽입 완료: 56개 제품
#
# 처리 중: 힌스_싱글_아이섀도우.csv
#   삽입 완료: 23개 제품
#
# 처리 중: 컬러그램_싱글_큐브_섀도우.csv
#   삽입 완료: 29개 제품
#
# 총 318개 제품 데이터베이스에 추가 완료
#
# 3. 통계 출력...
#
# ...
# 데이터베이스 통계
# ...
#
# 총 제품 수: 318
#
# 카테고리별:
#   eye: 318개
#
# 브랜드별 (상위 10개):
#   홀리카홀리카: 84개
#   롬앤: 56개
#   더샘: 35개
#   컬러그램: 29개
#   라카: 26개
#   아멜리: 26개
#   힌스: 23개
#   투크: 13개
#   데이지크: 10개
#   에뛰: 10개
#
# 피니시별:
#   unknown: 318개
# ...
#
# 4. 매칭용 데이터 export...
#
# ...

# %%
# !pip install groq --break-system-packages
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [groq]
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 11.4 MB/s  0:00:00 11.7 MB/s eta 0:00:01
# ...
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]━━━━━ 2/3 [scikit-learn]
# ...

# %%
# %cd /home/jeongmin/genai/models
# %run recommend_products.py /home/jeongmin/genai/data/celebrity_images/karina/15.jpg
# Out:
# /home/jeongmin/genai/models
# ...
# 얼굴 이미지 기반 메이크업 제품 추천 (색조 그룹 + ΔE 기반)
# ...
# 입력 이미지: /home/jeongmin/genai/data/celebrity_images/karina/15.jpg
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763368132.016854   29519 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1763368132.123682   32600 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 580.95.05), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1763368132.131719   32581 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1763368132.161056   32592 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
