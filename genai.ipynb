# %%
# %cd /home/jeongmin/genai
# %run backend/pipeline_test.py
# Out:
# /home/jeongmin/genai
# LAB(lips, cheeks, eyeshadow):
#   lips      -> (162.86, 157.54, 138.82)
#   cheeks    -> (204.93, 139.36, 137.15)
#   eyeshadow -> (191.03, 139.43, 137.29)
#
# ΔE(lips vs cheeks) = 45.861
# ΔE(lips vs eyeshadow) = 33.526
# ΔE(cheeks vs eyeshadow) = 13.901
#
# 저장 폴더: /home/jeongmin/genai/debug_out
# I0000 00:00:1762254163.413285  136078 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1762254163.536896  136836 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 580.95.05), renderer: NVIDIA GeForce RTX 3080/PCIe/SSE2
# W0000 00:00:1762254163.551286  136805 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762254163.580438  136810 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# %cd /home/jeongmin/genai/data
# %run build_product_db.py
# Out:
# /home/jeongmin/genai/data
# === K-뷰티 제품 데이터베이스 구축 ===
#
# 1. 데이터베이스 스키마 생성...
# 데이터베이스 생성 완료: /home/jeongmin/genai/data/db/products.db
#
# 2. CSV 파일 import...
#
# 처리 중: 투크_새틴_도화밤.csv
#   삽입 완료: 13개 제품
#
# 처리 중: 홀리카홀리카_마이페이브_피스_아이섀도우.csv
#   삽입 완료: 84개 제품
#
# 처리 중: 데이지크_블루밍_싱글_섀도우.csv
#   삽입 완료: 10개 제품
#
# 처리 중: 삐아_레디_투_웨어_아이섀도우.csv
#   삽입 완료: 6개 제품
#
# 처리 중: 에뛰_왓츠_인_마이_아이즈_&_더블.csv
#   삽입 완료: 10개 제품
#
# 처리 중: 더샘_샘물_싱글_섀도우.csv
#   삽입 완료: 35개 제품
#
# 처리 중: 아멜리_섀도.csv
#   삽입 완료: 26개 제품
#
# 처리 중: 라카_모노_아이섀도우.csv
#   삽입 완료: 26개 제품
#
# 처리 중: 롬앤_슬라이드_인_싱글.csv
#   삽입 완료: 56개 제품
#
# 처리 중: 힌스_싱글_아이섀도우.csv
#   삽입 완료: 23개 제품
#
# 처리 중: 컬러그램_싱글_큐브_섀도우.csv
#   삽입 완료: 29개 제품
#
# 총 318개 제품 데이터베이스에 추가 완료
#
# 3. 통계 출력...
#
# ...
# 데이터베이스 통계
# ...
#
# 총 제품 수: 318
#
# 카테고리별:
#   eye: 318개
#
# 브랜드별 (상위 10개):
#   홀리카홀리카: 84개
#   롬앤: 56개
#   더샘: 35개
#   컬러그램: 29개
#   라카: 26개
#   아멜리: 26개
#   힌스: 23개
#   투크: 13개
#   데이지크: 10개
#   에뛰: 10개
#
# 피니시별:
#   unknown: 318개
# ...
#
# 4. 매칭용 데이터 export...
#
# ...

# %%
# %cd /home/jeongmin/genai/data
# %run product_db_loader.py
# Out:
# /home/jeongmin/genai/data
# === 제품 DB 로더 테스트 ===
#
# 전체 제품 수: 318
# 아이섀도우 제품 수: 318
#
# 아이섀도우 제품 로드 (상위 5개):
#
# 1. 투크 - 새틴 도화밤
#    색상: 12 소프티
#    피니시: unknown
#    LAB: L=50.0, a=0.0, b=0.0
#
# 2. 투크 - 새틴 도화밤
#    색상: 13 이노센트
#    피니시: unknown
#    LAB: L=50.0, a=0.0, b=0.0
#
# 3. 투크 - 새틴 도화밤
#    색상: 07 메모러블
#    피니시: unknown
#    LAB: L=50.0, a=0.0, b=0.0
#
# 4. 투크 - 새틴 도화밤
#    색상: 01 스트로베리
#    피니시: unknown
#    LAB: L=50.0, a=0.0, b=0.0
#
# 5. 투크 - 새틴 도화밤
#    색상: 02 복숭아
#    피니시: unknown
#    LAB: L=50.0, a=0.0, b=0.0
#
#
# 총 로드된 아이섀도우: 318개
#
# === 테스트 완료 ===

# %%
# %cd /home/jeongmin/genai/data
# %run local_swatch_extractor.py
# Out:
# /home/jeongmin/genai/data
# === 로컬 이미지 색상 추출 테스트 ===
#
# 더미 이미지 생성 완료 (빨강 계열)
#
# 추출 결과:
#   최종 LAB: L=112.44, a=159.72, b=165.81
#
# 방법별 결과:
#   1. 공간적 중심:      L=78.79, a=154.03, b=157.9
#   2. 고채도 픽셀:      L=128.54, a=164.12, b=167.52
#   3. K-means 클러스터: L=130.0, a=161.0, b=172.0
#
# ...
# 사용 예시
# ...
#
# 1. 이미지 파일에서 색상 추출:
#   extractor = LocalSwatchColorExtractor()
#   result = extractor.process_image_file('/path/to/swatch.jpg')
#   print(f"LAB: {result['L']}, {result['a']}, {result['b']}")
#
# 2. 이미지 추출 + DB 업데이트:
#   extractor = LocalSwatchColorExtractor()
#   extractor.connect_db()
#   result = extractor.process_and_update(
#       product_id=1,
#       image_path='/home/jeongmin/genai/data/swatches/product1.jpg'
#   )
#   extractor.close_db()
#
# 3. 배치 처리:
#   import os
#   extractor = LocalSwatchColorExtractor()
#   extractor.connect_db()
#
#   swatch_dir = '/home/jeongmin/genai/data/swatches'
#   for filename in os.listdir(swatch_dir):
#       if filename.endswith('.jpg'):
# ...

# %%
# %cd /home/jeongmin/genai/data
# %run extract_swatch_colors.py
# Out:
# /home/jeongmin/genai/data
# === 스와치 이미지 색상 추출 ===
#
# 처리할 제품: 318개
#
# [1/318] 투크 - 12 소프티
#   성공: L=205.37, a=142.22, b=134.37
#
# [2/318] 투크 - 13 이노센트
#   성공: L=205.26, a=140.28, b=125.6
#
# [3/318] 투크 - 07 메모러블
#   성공: L=211.17, a=137.96, b=126.39
#
# [4/318] 투크 - 01 스트로베리
#   성공: L=173.77, a=156.06, b=135.21
#
# [5/318] 투크 - 02 복숭아
#   성공: L=198.29, a=144.02, b=131.17
#
# [6/318] 투크 - 03 벚꽃
#   성공: L=203.67, a=140.48, b=128.33
#
# [7/318] 투크 - 04 실루엣
#   성공: L=195.19, a=144.0, b=126.62
#
# [8/318] 투크 - 05 타로밀크
#   성공: L=202.7, a=136.8, b=126.7
#
# [9/318] 투크 - 06 로즈니
#   성공: L=195.22, a=143.17, b=132.49
#
# [10/318] 투크 - 08 투투
#   성공: L=199.38, a=142.0, b=130.51
#
# [11/318] 투크 - 09 모먼트 살몬
#   성공: L=196.83, a=140.53, b=134.02
#
# [12/318] 투크 - 10 피크
#   성공: L=184.34, a=149.89, b=132.08
#
# [13/318] 투크 - 11 데이즈
#   성공: L=188.4, a=144.46, b=136.88
#
# [14/318] 홀리카홀리카 - 시나몬 스파이스
#   성공: L=137.79, a=148.19, b=143.37
#
# [15/318] 홀리카홀리카 - 오버 더 피치
#   성공: L=190.44, a=159.47, b=143.81
# ...

# %%
# %cd /home/jeongmin/genai/data
# %run verify_lab_colors.py --html
# Out:
# /home/jeongmin/genai/data
#
# ✓ HTML 팔레트 생성 완료: /home/jeongmin/genai/output/color_palette.html
#   브라우저로 열어서 모든 제품의 색상을 확인하세요!
#
# 완료!
# /home/jeongmin/anaconda3/envs/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
